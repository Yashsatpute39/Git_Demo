# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
headers = {"User-Agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36"}

# %%
url= "https://www.amazon.in/gp/bestsellers/ref=zg_bs_tab"
page = requests.get(url, headers=headers)
soup = BeautifulSoup(page.content, 'lxml')

# %%
data = soup.find(class_="_p13n-zg-nav-tree-all_style_zg-browse-group__88fbz")
dept = data.find_all(class_="_p13n-zg-nav-tree-all_style_zg-browse-item__1rdKf _p13n-zg-nav-tree-all_style_zg-browse-height-small__nleKL")
first = dept[0]
first
# Out:
# <div class="_p13n-zg-nav-tree-all_style_zg-browse-item__1rdKf _p13n-zg-nav-tree-all_style_zg-browse-height-small__nleKL" role="treeitem"><a href="/gp/bestsellers/boost/ref=zg_bs_nav_0">Amazon Launchpad</a></div>

# %%
deptname = first.find('a').get_text()
link = first.find('a')

# %%
#for dept and links
name , link = [], []
for i in dept:
    name.append(i.find('a').get_text())
    li = i.find('a', href=True)
    link.append(li['href'])
DeptLink = {"Dept_Name":name, "Dept_Link":link}

# %%
soup2 = []
for l in link:
    url = f"https://www.amazon.in/{l}"
    page = requests.get(url)
    soup1 = BeautifulSoup(page.content, 'lxml')
    soup2.append(soup1)

# %%
first1 = soup2[0]
first1
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <!-- sp:end-feature:csm:head-open-part2 -->
# <!-- sp:feature:aui-assets -->
# ...

# %%
#for sub_depart_linksoup
sub_depart, sub_depart_link = [], []
for x in soup2:
    #data1 = x.find(class_="_p13n-zg-nav-tree-all_style_zg-browse-group__88fbz")
    data2 = x.find_all(class_="_p13n-zg-nav-tree-all_style_zg-browse-item__1rdKf _p13n-zg-nav-tree-all_style_zg-browse-height-large__1z5B8")
    
    for m in data2[1:]:
        sub_depart.append(m.find('a').get_text())
        lin = m.find('a', href=True)
        sub_depart_link.append(lin['href'])
Sub_Depart = {"Sub_Depart Name":sub_depart, "Sub_Depart_Link":sub_depart_link}

# %%
# for Child sub_depart_link
soup4 = []
for n in sub_depart_link:
    url = f"https://www.amazon.in/{n}"
    page = requests.get(url)
    soup3 = BeautifulSoup(page.content, 'lxml')
    soup4.append(soup3)

# %%
Ch_sub_depart,Ch_sub_depart_link = [], []
for z in soup4:
    data4 = z.find_all(class_="_p13n-zg-nav-tree-all_style_zg-browse-item__1rdKf _p13n-zg-nav-tree-all_style_zg-browse-height-large__1z5B8")
    for d in data4[1:]:
        if d.find('a'):
            Ch_sub_depart.append(d.find('a').get_text())
            linkk = m.find('a', href=True)
            Ch_sub_depart_link.append(linkk['href'])
        else:
            Ch_sub_depart.append(None)
            Ch_sub_depart_link.append(None)
#Child_Sub_Depart = {"Child_Sub_Depart": Ch_sub_depart, "Child_Sub_Depart_Lnk":Ch_sub_depart_link}
data4
# Out:
# [<div class="_p13n-zg-nav-tree-all_style_zg-browse-item__1rdKf _p13n-zg-nav-tree-all_style_zg-browse-height-large__1z5B8" role="treeitem"><span class="_p13n-zg-nav-tree-all_style_zg-selected__1SfhQ">Women</span></div>,
#  <div class="_p13n-zg-nav-tree-all_style_zg-browse-item__1rdKf _p13n-zg-nav-tree-all_style_zg-browse-height-large__1z5B8" role="treeitem"><a href="/gp/bestsellers/watches/15723942031">Fashion Smartwatches</a></div>,
#  <div class="_p13n-zg-nav-tree-all_style_zg-browse-item__1rdKf _p13n-zg-nav-tree-all_style_zg-browse-height-large__1z5B8" role="treeitem"><a href="/gp/bestsellers/watches/15723941031">Wrist Watches</a></div>]

# %%
DeptLink
# Out:
# {'Dept_Name': ['Amazon Launchpad',
#   'Amazon Renewed',
#   'Apps for Android',
#   'Baby Products',
#   'Bags, Wallets and Luggage',
#   'Beauty',
#   'Books',
#   'Car & Motorbike',
#   'Clothing & Accessories',
#   'Computers & Accessories',
#   'Electronics',
#   'Garden & Outdoors',
#   'Gift Cards',
#   'Grocery & Gourmet Foods',
#   'Health & Personal Care',
#   'Home & Kitchen',
#   'Home Improvement',
#   'Industrial & Scientific',
#   'Jewellery',
#   'Kindle Store',
#   'Movies & TV Shows',
#   'Music',
#   'Musical Instruments',
#   'Office Products',
#   'Pet Supplies',
#   'Shoes & Handbags',
#   'Software',
#   'Sports, Fitness & Outdoors',
#   'Toys & Games',
#   'Video Games',
#   'Watches'],
#  'Dept_Link': ['/gp/bestsellers/boost/ref=zg_bs_nav_0',
#   '/gp/bestsellers/amazon-renewed/ref=zg_bs_nav_0',
#   '/gp/bestsellers/mobile-apps/ref=zg_bs_nav_0',
#   '/gp/bestsellers/baby/ref=zg_bs_nav_0',
#   '/gp/bestsellers/luggage/ref=zg_bs_nav_0',
# ...

# %%
Sub_Depart
# Out:
# {'Sub_Depart Name': ['Body',
#   'Collections',
#   'Electronics',
#   'Fashion Accessories',
#   'Food',
#   'Home',
#   'Toys & Baby',
#   'Books & Comics',
#   'Business',
#   'Communication',
#   'Customization',
#   'Education',
#   'Finance',
#   'Food & Drink',
#   'Games',
#   'Health & Fitness',
#   'Kids',
#   'Lifestyle',
#   'Local',
#   'Magazines',
#   'Medical',
#   'Movies & TV',
#   'Music & Audio',
#   'News',
#   'Novelty',
#   'Photo & Video',
#   'Productivity',
#   'Reference',
#   'Shopping',
#   'Social',
#   'Sports',
#   'Transportation',
#   'Travel',
#   'Utilities',
#   'Weather',
#   'Activity & Entertainment',
#   'Baby & Toddler Toys',
#   'Baby Care',
#   'Baby Carriers',
#   'Baby Shoes',
#   'Car Seats & Accessories',
#   'Maternity',
#   'Nappy Changing',
#   'Nursery',
#   'Nursing & Feeding',
#   'Potty Training & Step Stools',
#   'Safety Equipment',
#   'Soothers & Teethers',
#   'Strollers & Prams',
#   'Backpacks',
#   'Bags & Briefcases',
# ...

# %%
Child_Sub_Depart
# Out:
# {'Child_Sub_Depart': ['Disruptive Innovations',
#   'Internet of Things',
#   'Life Hacks',
#   'Startups from India',
#   'Top Picks',
#   'Office Products',
#   'Body',
#   'Collections',
#   'Electronics',
#   None,
#   'Food',
#   'Home',
#   'Toys & Baby',
#   'Grocery',
#   'Home & Furniture',
#   'Kitchen',
#   'Baby',
#   'Toys',
#   None,
#   'Business',
#   'Communication',
#   'Customization',
#   'Education',
#   'Finance',
#   'Food & Drink',
#   'Games',
#   'Health & Fitness',
#   'Kids',
#   'Lifestyle',
#   'Local',
#   'Magazines',
#   'Medical',
#   'Movies & TV',
#   'Music & Audio',
#   'News',
#   'Novelty',
#   'Photo & Video',
#   'Productivity',
#   'Reference',
#   'Shopping',
#   'Social',
#   'Sports',
#   'Transportation',
#   'Travel',
#   'Utilities',
#   'Weather',
#   'Books & Comics',
#   'Business',
#   None,
#   'Customization',
#   'Education',
#   'Finance',
#   'Food & Drink',
#   'Games',
#   'Health & Fitness',
#   'Kids',
#   'Lifestyle',
# ...
